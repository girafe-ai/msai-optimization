# %%
import numpy as np
import cvxpy as cp
import matplotlib.pyplot as plt

# %%
cp.installed_solvers()
# Out:
# ['CVXOPT',
#  'ECOS',
#  'ECOS_BB',
#  'GLPK',
#  'GLPK_MI',
#  'GUROBI',
#  'MOSEK',
#  'OSQP',
#  'SCIPY',
#  'SCS']

# %% [markdown]
# ## Sparse index fund

# %%
# number of stocks
n = 500
# number of factors (not described or needed in problem statement)
k = 20

# generate rbar, Sigma
# factor matrix, entries uniform on [-0.5,1]
F = 1.5 * np.random.rand(n, k) - 0.5
Sigma = 0.5 * F @ np.diag(np.random.rand(k)) @ F.T + np.diag(0.1 * np.random.rand(n))
# risk-free return (weekly, 5% annual)
mu_rf = 0.2
# Sharpe ratio
SR = 0.4
# expected return
rbar = mu_rf + SR * np.sqrt(np.diag(Sigma))
# market capitalization (index weights)
c = 5 + np.exp(2 * np.random.randn(n))

# %%
num_samples = 10000
r = np.random.multivariate_normal(rbar, Sigma, num_samples)
print(r.shape)
# Out:
# (10000, 500)

# %%
rhs = r @ c
threshold = 1e-1

# %%
w = cp.Variable(n)

obj = cp.Minimize(cp.norm1(w))
constr = [cp.norm2(r @ w - rhs) <= threshold * np.linalg.norm(rhs)]

problem = cp.Problem(obj, constr)
problem.solve(solver=cp.MOSEK, verbose=True)
# Out:
# ===============================================================================
#                                      CVXPY
#                                      v1.2.2
# ===============================================================================
# (CVXPY) Nov 22 07:32:13 PM: Your problem has 500 variables, 1 constraints, and 0 parameters.
# (CVXPY) Nov 22 07:32:13 PM: It is compliant with the following grammars: DCP, DQCP
# (CVXPY) Nov 22 07:32:13 PM: (If you need to solve this problem multiple times, but with different data, consider using parameters.)
# (CVXPY) Nov 22 07:32:13 PM: CVXPY will first compile your problem; then, it will invoke a numerical solver to obtain a solution.
# -------------------------------------------------------------------------------
#                                   Compilation
# -------------------------------------------------------------------------------
# (CVXPY) Nov 22 07:32:13 PM: Compiling problem (target solver=MOSEK).
# (CVXPY) Nov 22 07:32:13 PM: Reduction chain: Dcp2Cone -> CvxAttr2Constr -> ConeMatrixStuffing -> MOSEK
# (CVXPY) Nov 22 07:32:13 PM: Applying reduction Dcp2Cone
# (CVXPY) Nov 22 07:32:13 PM: Applying reduction CvxAttr2Constr
# (CVXPY) Nov 22 07:32:13 PM: Applying reduction ConeMatrixStuffing
# (CVXPY) Nov 22 07:32:13 PM: Applying reduction MOSEK
# (CVXPY) Nov 22 07:32:14 PM: Finished problem compilation (took 1.224e+00 seconds).
# -------------------------------------------------------------------------------
#                                 Numerical solver
# -------------------------------------------------------------------------------
# (CVXPY) Nov 22 07:32:14 PM: Invoking solver MOSEK  to obtain a solution.
#
#
# (CVXPY) Nov 22 07:32:15 PM: Problem
# (CVXPY) Nov 22 07:32:15 PM:   Name                   :
# (CVXPY) Nov 22 07:32:15 PM:   Objective sense        : maximize
# (CVXPY) Nov 22 07:32:15 PM:   Type                   : CONIC (conic optimization problem)
# (CVXPY) Nov 22 07:32:15 PM:   Constraints            : 1001
# (CVXPY) Nov 22 07:32:15 PM:   Affine conic cons.     : 0
# (CVXPY) Nov 22 07:32:15 PM:   Disjunctive cons.      : 0
# (CVXPY) Nov 22 07:32:15 PM:   Cones                  : 1
# (CVXPY) Nov 22 07:32:15 PM:   Scalar variables       : 11002
# (CVXPY) Nov 22 07:32:15 PM:   Matrix variables       : 0
# (CVXPY) Nov 22 07:32:15 PM:   Integer variables      : 0
# (CVXPY) Nov 22 07:32:15 PM:
# (CVXPY) Nov 22 07:32:15 PM: Optimizer started.
# (CVXPY) Nov 22 07:32:15 PM: Presolve started.
# (CVXPY) Nov 22 07:32:15 PM: Linear dependency checker started.
# (CVXPY) Nov 22 07:32:15 PM: Linear dependency checker terminated.
# (CVXPY) Nov 22 07:32:15 PM: Eliminator started.
# (CVXPY) Nov 22 07:32:15 PM: Freed constraints in eliminator : 501
# (CVXPY) Nov 22 07:32:15 PM: Eliminator terminated.
# (CVXPY) Nov 22 07:32:15 PM: Eliminator started.
# (CVXPY) Nov 22 07:32:16 PM: Freed constraints in eliminator : 0
# (CVXPY) Nov 22 07:32:16 PM: Eliminator terminated.
# (CVXPY) Nov 22 07:32:16 PM: Eliminator - tries                  : 2                 time                   : 0.00
# (CVXPY) Nov 22 07:32:16 PM: Lin. dep.  - tries                  : 1                 time                   : 0.02
# (CVXPY) Nov 22 07:32:16 PM: Lin. dep.  - number                 : 0
# (CVXPY) Nov 22 07:32:16 PM: Presolve terminated. Time: 0.44
# (CVXPY) Nov 22 07:32:16 PM: GP based matrix reordering started.
# (CVXPY) Nov 22 07:32:16 PM: GP based matrix reordering terminated.
# (CVXPY) Nov 22 07:32:16 PM: Problem
# (CVXPY) Nov 22 07:32:16 PM:   Name                   :
# (CVXPY) Nov 22 07:32:16 PM:   Objective sense        : maximize
# (CVXPY) Nov 22 07:32:16 PM:   Type                   : CONIC (conic optimization problem)
# (CVXPY) Nov 22 07:32:16 PM:   Constraints            : 1001
# (CVXPY) Nov 22 07:32:16 PM:   Affine conic cons.     : 0
# (CVXPY) Nov 22 07:32:16 PM:   Disjunctive cons.      : 0
# (CVXPY) Nov 22 07:32:16 PM:   Cones                  : 1
# (CVXPY) Nov 22 07:32:16 PM:   Scalar variables       : 11002
# (CVXPY) Nov 22 07:32:16 PM:   Matrix variables       : 0
# (CVXPY) Nov 22 07:32:16 PM:   Integer variables      : 0
# (CVXPY) Nov 22 07:32:16 PM:
# (CVXPY) Nov 22 07:32:16 PM: Optimizer  - threads                : 8
# (CVXPY) Nov 22 07:32:16 PM: Optimizer  - solved problem         : the primal
# (CVXPY) Nov 22 07:32:16 PM: Optimizer  - Constraints            : 500
# (CVXPY) Nov 22 07:32:16 PM: Optimizer  - Cones                  : 1
# (CVXPY) Nov 22 07:32:16 PM: Optimizer  - Scalar variables       : 10501             conic                  : 10001
# (CVXPY) Nov 22 07:32:16 PM: Optimizer  - Semi-definite variables: 0                 scalarized             : 0
# (CVXPY) Nov 22 07:32:16 PM: Factor     - setup time             : 0.11              dense det. time        : 0.00
# (CVXPY) Nov 22 07:32:16 PM: Factor     - ML order time          : 0.00              GP order time          : 0.00
# (CVXPY) Nov 22 07:32:16 PM: Factor     - nonzeros before factor : 1.25e+05          after factor           : 1.25e+05
# (CVXPY) Nov 22 07:32:16 PM: Factor     - dense dim.             : 0                 flops                  : 2.55e+09
# (CVXPY) Nov 22 07:32:16 PM: Factor     - GP saved nzs           : 0                 GP saved flops         : 2.50e+09
# (CVXPY) Nov 22 07:32:16 PM: ITE PFEAS    DFEAS    GFEAS    PRSTATUS   POBJ              DOBJ              MU       TIME
# (CVXPY) Nov 22 07:32:16 PM: 0   8.8e-01  5.3e+04  5.3e+04  0.00e+00   -5.260004533e+04  0.000000000e+00   1.0e+00  0.76
# (CVXPY) Nov 22 07:32:16 PM: 1   4.4e-03  2.7e+02  3.7e+03  -1.00e+00  -2.642702952e+04  2.577989540e+04   5.0e-03  0.83
# (CVXPY) Nov 22 07:32:16 PM: 2   2.3e-03  1.4e+02  2.7e+03  -9.85e-01  -3.267399224e+03  4.802856838e+04   2.7e-03  0.89
# (CVXPY) Nov 22 07:32:16 PM: 3   2.3e-03  1.4e+02  2.3e+03  -4.70e-01  -2.621454877e+03  4.282958336e+04   2.6e-03  0.94
# (CVXPY) Nov 22 07:32:16 PM: 4   2.1e-03  1.2e+02  3.4e+02  1.58e+00   -2.902997663e+03  1.882559088e+04   2.4e-03  0.99
# (CVXPY) Nov 22 07:32:16 PM: 5   7.7e-04  4.6e+01  9.4e+01  1.65e+00   2.292366679e+03   7.058082953e+03   8.8e-04  1.05
# (CVXPY) Nov 22 07:32:16 PM: 6   1.4e-04  8.4e+00  5.6e+00  1.16e+00   4.249664477e+03   5.019145762e+03   1.6e-04  1.12
# (CVXPY) Nov 22 07:32:16 PM: 7   2.2e-05  1.3e+00  4.2e-01  1.04e+00   4.422906705e+03   4.537811840e+03   2.5e-05  1.19
# (CVXPY) Nov 22 07:32:16 PM: 8   3.9e-06  2.3e-01  4.1e-02  1.02e+00   4.393791471e+03   4.414324875e+03   4.5e-06  1.27
# (CVXPY) Nov 22 07:32:16 PM: 9   5.8e-07  3.5e-02  2.5e-03  1.00e+00   4.387287223e+03   4.390329394e+03   6.6e-07  1.32
# (CVXPY) Nov 22 07:32:16 PM: 10  1.4e-07  8.7e-03  3.1e-04  1.00e+00   4.386200353e+03   4.386961847e+03   1.7e-07  1.39
# (CVXPY) Nov 22 07:32:16 PM: 11  1.5e-08  8.9e-04  1.0e-05  1.00e+00   4.385864355e+03   4.385942432e+03   1.7e-08  1.44
# (CVXPY) Nov 22 07:32:16 PM: 12  1.3e-11  7.6e-07  2.5e-10  1.00e+00   4.385823977e+03   4.385824043e+03   1.4e-11  1.51
# (CVXPY) Nov 22 07:32:17 PM: 13  1.7e-11  2.9e-06  2.0e-13  1.00e+00   4.385823972e+03   4.385823943e+03   4.9e-17  1.58
# (CVXPY) Nov 22 07:32:17 PM: Optimizer terminated. Time: 1.60
# (CVXPY) Nov 22 07:32:17 PM:
# (CVXPY) Nov 22 07:32:17 PM:
# (CVXPY) Nov 22 07:32:17 PM: Interior-point solution summary
# (CVXPY) Nov 22 07:32:17 PM:   Problem status  : PRIMAL_AND_DUAL_FEASIBLE
# (CVXPY) Nov 22 07:32:17 PM:   Solution status : OPTIMAL
# (CVXPY) Nov 22 07:32:17 PM:   Primal.  obj: 4.3858239723e+03    nrm: 1e+00    Viol.  con: 7e-09    var: 1e-14    cones: 1e-17
# (CVXPY) Nov 22 07:32:17 PM:   Dual.    obj: 4.3858239433e+03    nrm: 5e+04    Viol.  con: 0e+00    var: 3e-04    cones: 1e-10
# -------------------------------------------------------------------------------
#                                     Summary
# -------------------------------------------------------------------------------
# (CVXPY) Nov 22 07:32:17 PM: Problem status: optimal
# (CVXPY) Nov 22 07:32:17 PM: Optimal value: 4.386e+03
# (CVXPY) Nov 22 07:32:17 PM: Compilation took 1.224e+00 seconds
# (CVXPY) Nov 22 07:32:17 PM: Solver (including time spent in interface) took 2.735e+00 seconds
# 4385.823943324029

# %%
np.linalg.norm(r @ w.value - rhs) / np.linalg.norm(rhs)
# Out:
# 0.10000000000000178

# %%
np.sum(np.abs(w.value) > 0.05), np.sum(np.abs(c) > 0.05)
# Out:
# (39, 500)

# %%
plt.figure(figsize=(10,7))
plt.plot(w.value, label="Sparse")
plt.plot(c, label="Initial")
plt.yscale("log")
plt.legend()

# %% [markdown]
# # Sparse covariance estimation for Gaussian variables
#
# ## Introduction
#
# Suppose $y \in \mathbf{\mbox{R}}^n$ is a Gaussian random variable with zero mean and
# covariance matrix $R = \mathbf{\mbox{E}}[yy^T]$, with sparse inverse $S = R^{-1}$
# ($S_{ij} = 0$ means that $y_i$ and $y_j$ are conditionally independent).
# We want to estimate the covariance matrix $R$ based on $N$ independent
# samples $y_1,\dots,y_N$ drawn from the distribution, and using prior knowledge
# that $S$ is sparse
#
# A good heuristic for estimating $R$ is to solve the problem
#   $$\begin{array}{ll}
#     \mbox{maximize}   & \log \det(S) - \mbox{tr}(SY) \\
#     \mbox{subject to} & \sum_{i=1}^n \sum_{j=1}^n |S_{ij}| \le \alpha \\
#                       & S \succeq 0,
#     \end{array}$$
# where $Y$ is the sample covariance of $y_1,\dots,y_N$, and $\alpha$ is a sparsity
# parameter to be chosen or tuned.
#
# **Remark**: more detailed description of the objective function is given [here](http://people.eecs.berkeley.edu/~jordan/courses/260-spring10/other-readings/chapter13.pdf), in particular eq. (13.50)
#
# ## Generate problem data

# %%
import cvxpy as cp
import numpy as np
import scipy as scipy

# Dimension of matrix.
n = 10

# Number of samples, y_i
N = 1000

# Create sparse, symmetric PSD matrix S
A = np.random.randn(n, n)  # Unit normal gaussian distribution.
A[scipy.sparse.rand(n, n, 0.85).todense().nonzero()] = 0  # Sparsen the matrix.
Strue = A.dot(A.T) + 0.05 * np.eye(n)  # Force strict pos. def.

# Create the covariance matrix associated with S.
R = np.linalg.inv(Strue)

# Create samples y_i from the distribution with covariance R. 
y_sample = scipy.linalg.sqrtm(R).dot(np.random.randn(n, N))

# Calculate the sample covariance matrix.
Y = np.cov(y_sample)

# %%
alpha = 7
S = cp.Variable(shape=(n,n), PSD=True)
obj = cp.Maximize(cp.log_det(S) - cp.trace(S @ Y))

# Set constraint.
constraints = [cp.sum(cp.abs(S)) <= alpha]

# Form and solve optimization problem
prob = cp.Problem(obj, constraints)
prob.solve(solver=cp.SCS, verbose=True)

# If the covariance matrix R is desired, here is how it to create it.
R_hat = np.linalg.inv(S.value)
# Out:
# ===============================================================================
#                                      CVXPY
#                                      v1.2.2
# ===============================================================================
# (CVXPY) Nov 22 08:00:44 PM: Your problem has 100 variables, 1 constraints, and 0 parameters.
# (CVXPY) Nov 22 08:00:44 PM: It is compliant with the following grammars: DCP, DQCP
# (CVXPY) Nov 22 08:00:44 PM: (If you need to solve this problem multiple times, but with different data, consider using parameters.)
# (CVXPY) Nov 22 08:00:44 PM: CVXPY will first compile your problem; then, it will invoke a numerical solver to obtain a solution.
# -------------------------------------------------------------------------------
#                                   Compilation
# -------------------------------------------------------------------------------
# (CVXPY) Nov 22 08:00:44 PM: Compiling problem (target solver=SCS).
# (CVXPY) Nov 22 08:00:44 PM: Reduction chain: FlipObjective -> Dcp2Cone -> CvxAttr2Constr -> ConeMatrixStuffing -> SCS
# (CVXPY) Nov 22 08:00:44 PM: Applying reduction FlipObjective
# (CVXPY) Nov 22 08:00:44 PM: Applying reduction Dcp2Cone
# (CVXPY) Nov 22 08:00:44 PM: Applying reduction CvxAttr2Constr
# (CVXPY) Nov 22 08:00:44 PM: Applying reduction ConeMatrixStuffing
# (CVXPY) Nov 22 08:00:44 PM: Applying reduction SCS
# (CVXPY) Nov 22 08:00:44 PM: Finished problem compilation (took 1.866e-02 seconds).
# -------------------------------------------------------------------------------
#                                 Numerical solver
# -------------------------------------------------------------------------------
# (CVXPY) Nov 22 08:00:44 PM: Invoking solver SCS  to obtain a solution.
# ------------------------------------------------------------------
# 	       SCS v3.2.2 - Splitting Conic Solver
# 	(c) Brendan O'Donoghue, Stanford University, 2012
# ------------------------------------------------------------------
# problem:  variables n: 220, constraints m: 496
# cones: 	  l: linear vars: 201
# 	  s: psd vars: 265, ssize: 2
# 	  e: exp vars: 30, dual exp vars: 0
# settings: eps_abs: 1.0e-05, eps_rel: 1.0e-05, eps_infeas: 1.0e-07
# 	  alpha: 1.50, scale: 1.00e-01, adaptive_scale: 1
# 	  max_iters: 100000, normalize: 1, rho_x: 1.00e-06
# 	  acceleration_lookback: 10, acceleration_interval: 10
# lin-sys:  sparse-direct-amd-qdldl
# 	  nnz(A): 695, nnz(P): 0
# ------------------------------------------------------------------
#  iter | pri res | dua res |   gap   |   obj   |  scale  | time (s)
# ------------------------------------------------------------------
#      0| 1.18e+02  1.19e+01  1.05e+04 -5.25e+03  1.00e-01  1.41e-03
#    250| 3.28e-02  6.67e-03  1.75e+00  2.21e+01  8.87e-01  4.17e-02
#    500| 2.88e-03  3.32e-03  1.92e-01  2.43e+01  2.82e+00  1.18e-01
#    750| 1.52e-05  6.09e-06  3.77e-04  2.44e+01  2.82e+00  1.81e-01
#    825| 6.06e-07  8.71e-06  7.01e-05  2.44e+01  2.82e+00  2.35e-01
# ------------------------------------------------------------------
# status:  solved
# timings: total: 2.35e-01s = setup: 6.91e-04s + solve: 2.34e-01s
# 	 lin-sys: 9.63e-03s, cones: 2.03e-01s, accel: 1.57e-02s
# ------------------------------------------------------------------
# objective = 24.403352
# ------------------------------------------------------------------
# -------------------------------------------------------------------------------
#                                     Summary
# -------------------------------------------------------------------------------
# (CVXPY) Nov 22 08:00:45 PM: Problem status: optimal
# (CVXPY) Nov 22 08:00:45 PM: Optimal value: -2.440e+01
# (CVXPY) Nov 22 08:00:45 PM: Compilation took 1.866e-02 seconds
# (CVXPY) Nov 22 08:00:45 PM: Solver (including time spent in interface) took 2.356e-01 seconds

# %%
# Threshold S element values to enforce exact zeros:
S = S.value
S[abs(S) <= 1e-4] = 0

# %%
import matplotlib.pyplot as plt

# Show plot inline in ipython.
# %matplotlib inline

# Plot properties.
plt.rc('text', usetex=True)
plt.rc('font', family='serif')

# Create figure.
plt.figure()
plt.figure(figsize=(12, 12))

# Plot sparsity pattern for the true covariance matrix.
plt.subplot(2, 2, 1)
plt.spy(Strue)
plt.title('Inverse of true covariance matrix', fontsize=16)
plt.show()

# Plot sparsity pattern for each result, corresponding to a specific alpha.
plt.spy(S)
plt.title('Estimated inv. cov matrix, $\\alpha$={}'.format(alpha), fontsize=16)
# Out:
# Text(0.5, 1.0, 'Estimated inv. cov matrix, $\\alpha$=7')

# %%
x = cp.Variable(2)
# problem = cp.Problem(cp.Minimize(cp.norm(x)), [x[0] >= 0, x[1] * x[0] >= 0])
problem = cp.Problem(cp.Minimize(cp.norm(x)), [cp.bmat([[x[0], 0], [0, x[1]]]) >> 0])
problem.solve(solver=cp.SCS)
# Out:
# 0.0

# %%
x.value
